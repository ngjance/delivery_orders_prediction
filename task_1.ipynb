# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.arima_model import ARMA
from statsmodels.tsa.ar_model import AR
from sklearn.metrics import mean_absolute_error
from statsmodels.tsa.stattools import adfuller  

# %matplotlib inline

import warnings
warnings.simplefilter(action="ignore")

import sqlite3
# Out:
# C:\Users\ng_li\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
order = pd.read_csv('./orders_data.csv')
order.head()
# Out:
#   Created Date   Country    City  Restaurant ID  \
# 0   28.02.2020  Portugal  Lisbon           7238
# 1   28.02.2020  Portugal  Lisbon          12758
# 2   28.02.2020  Portugal  Lisbon           6631
# 3   28.02.2020  Portugal  Lisbon          10535
# 4   28.02.2020  Portugal  Lisbon           9695
#
#                       Restaurant Name Order State Cancel Reason  \
# 0                 Chirashi - Alvalade   delivered           NaN
# 1      Istanbul Kebab Pizza - Alameda   delivered           NaN
# 2                      A-100 - Lisboa   delivered           NaN
# 3  La Paparrucha - Parrilla Argentina   delivered           NaN
# 4                      Choupana Caffe   delivered           NaN
#
#           Cuisine Platform  Products in Order Order Value € (Gross)  \
# 0           Sushi      ios                 13                €89.30
# 1           Pizza  android                  1                €10.00
# 2         Burgers      ios                  2                €16.96
# 3  South American      ios                  3                €25.15
# 4          Brunch      ios                  3                €16.00
#
#    Delivery Fee  Delivery Time  Order ID
# 0           0.0           17.7      1381
# 1           0.0           16.3      2382
# 2           0.0           13.6      3383
# 3           4.2           26.1      4384
# 4           0.0           11.6      5385

# %%
order.columns = order.columns.str.replace('€ (Gross)', 'Gross', regex=False)

# %%
# change column name to lowercase and replace ' ' with '_'
order.columns = order.columns.str.replace(' ', '_', regex=False).str.lower()

# %%
order.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99618 entries, 0 to 99617
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   created_date       99618 non-null  object
#  1   country            99618 non-null  object
#  2   city               99618 non-null  object
#  3   restaurant_id      99618 non-null  int64
#  4   restaurant_name    99618 non-null  object
#  5   order_state        99618 non-null  object
#  6   cancel_reason      1682 non-null   object
#  7   cuisine            99291 non-null  object
#  8   platform           87684 non-null  object
#  9   products_in_order  99618 non-null  int64
#  10  order_value_gross  97936 non-null  object
#  11  delivery_fee       97936 non-null  float64
#  12  delivery_time      97936 non-null  float64
#  13  order_id           99618 non-null  int64
# dtypes: float64(2), int64(3), object(9)
# memory usage: 10.6+ MB

# %%
order["created_date"]= pd.to_datetime(order["created_date"], format="%d.%m.%Y", infer_datetime_format=True)

# %%
order["order_value_gross"] = order["order_value_gross"].str.strip('€')

# %%
order["order_value_gross"] = order["order_value_gross"].astype(float)

# %%
order.head()
# Out:
#   created_date   country    city  restaurant_id  \
# 0   2020-02-28  Portugal  Lisbon           7238
# 1   2020-02-28  Portugal  Lisbon          12758
# 2   2020-02-28  Portugal  Lisbon           6631
# 3   2020-02-28  Portugal  Lisbon          10535
# 4   2020-02-28  Portugal  Lisbon           9695
#
#                       restaurant_name order_state cancel_reason  \
# 0                 Chirashi - Alvalade   delivered           NaN
# 1      Istanbul Kebab Pizza - Alameda   delivered           NaN
# 2                      A-100 - Lisboa   delivered           NaN
# 3  La Paparrucha - Parrilla Argentina   delivered           NaN
# 4                      Choupana Caffe   delivered           NaN
#
#           cuisine platform  products_in_order  order_value_gross  \
# 0           Sushi      ios                 13              89.30
# 1           Pizza  android                  1              10.00
# 2         Burgers      ios                  2              16.96
# 3  South American      ios                  3              25.15
# 4          Brunch      ios                  3              16.00
#
#    delivery_fee  delivery_time  order_id
# 0           0.0           17.7      1381
# 1           0.0           16.3      2382
# 2           0.0           13.6      3383
# 3           4.2           26.1      4384
# 4           0.0           11.6      5385

# %%
order.isnull().sum()
# Out:
# created_date             0
# country                  0
# city                     0
# restaurant_id            0
# restaurant_name          0
# order_state              0
# cancel_reason        97936
# cuisine                327
# platform             11934
# products_in_order        0
# order_value_gross     1682
# delivery_fee          1682
# delivery_time         1682
# order_id                 0
# dtype: int64

# %%
order['order_state'].unique()
# Out:
# array(['delivered', 'failed', 'rejected'], dtype=object)

# %%
order[order['order_state']=='delivered'].isnull().sum()
# Out:
# created_date             0
# country                  0
# city                     0
# restaurant_id            0
# restaurant_name          0
# order_state              0
# cancel_reason        97936
# cuisine                323
# platform             11707
# products_in_order        0
# order_value_gross        0
# delivery_fee             0
# delivery_time            0
# order_id                 0
# dtype: int64

# %%
order[(order['order_state']=='failed')|(order['order_state']=='rejected')].isnull().sum()
# Out:
# created_date            0
# country                 0
# city                    0
# restaurant_id           0
# restaurant_name         0
# order_state             0
# cancel_reason           0
# cuisine                 4
# platform              227
# products_in_order       0
# order_value_gross    1682
# delivery_fee         1682
# delivery_time        1682
# order_id                0
# dtype: int64

# %%
# if dtype = object, fill NaN with 'NA'
# if dtype = int or float, fill NaN with 0
for col in order:
    #get dtype for column
    dt = order[col].dtype 
    #check if it is a number
    if dt == int or dt == float:
        order[col].fillna(0, inplace=True)
    else:
        order[col].fillna('NA', inplace=True)

# %%
order.isnull().sum()
# Out:
# created_date         0
# country              0
# city                 0
# restaurant_id        0
# restaurant_name      0
# order_state          0
# cancel_reason        0
# cuisine              0
# platform             0
# products_in_order    0
# order_value_gross    0
# delivery_fee         0
# delivery_time        0
# order_id             0
# dtype: int64

# %%
payment = pd.read_csv('./orders_payments_info.csv')
payment.head()
# Out:
#    Order ID Payment Method                     Card Issuer
# 0      1381       cashless                  BANKINTER S.A.
# 1      2382       cashless  BANCO COMERCIAL PORTUGUES S.A.
# 2      3383       cashless  BANCO COMERCIAL PORTUGUES S.A.
# 3      4384       cashless                   ING BANK N.V.
# 4      5385       cashless             INTESA SANPAOLO SPA

# %%
# change column name to lowercase and replace ' ' with '_'
payment.columns = payment.columns.str.replace(' ', '_', regex=False).str.lower()

# %%
payment.isnull().sum()
# Out:
# order_id              0
# payment_method        0
# card_issuer       12712
# dtype: int64

# %%
payment['payment_method'].unique()
# Out:
# array(['cashless', 'cash'], dtype=object)

# %%
payment[payment['payment_method']=='cash'].isnull().sum()
# Out:
# order_id             0
# payment_method       0
# card_issuer       5761
# dtype: int64

# %%
payment['payment_method'].fillna('NA', inplace=True)

# %%
payment.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99618 entries, 0 to 99617
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   order_id        99618 non-null  int64
#  1   payment_method  99618 non-null  object
#  2   card_issuer     86906 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 2.3+ MB

# %%
conn = sqlite3.connect("data.db")

# %%
c = conn.cursor()
c.execute('''DROP TABLE IF EXISTS [orders,payment]''')
order.to_sql('orders', conn, if_exists='replace', index=False)
# Out:
# 99618

# %% [markdown]
# c.execute('''DROP TABLE IF EXISTS orders''')
# payment.to_sql('payment', conn, if_exists='replace', index=False)

# %% [markdown]
# conn.row_factory = sqlite3.Row

# %%
def execute_sql(sql):
    """
    Functions to execute results and return as dataframe
    """
   
    result = pd.read_sql(sql, conn)
    return pd.DataFrame(result)

# %%
sql = """SELECT created_date FROM orders limit 5"""
execute_sql(sql)
# Out:
#           created_date
# 0  2020-02-28 00:00:00
# 1  2020-02-28 00:00:00
# 2  2020-02-28 00:00:00
# 3  2020-02-28 00:00:00
# 4  2020-02-28 00:00:00

# %%
c.execute("SELECT *\
from orders limit 5")
          
          
rows = c.fetchall()
rows
# Out:
# [('2020-02-28 00:00:00',
#   'Portugal',
#   'Lisbon',
#   7238,
#   'Chirashi - Alvalade',
#   'delivered',
#   'NA',
#   'Sushi',
#   'ios',
#   13,
#   89.3,
#   0.0,
#   17.7,
#   1381),
#  ('2020-02-28 00:00:00',
#   'Portugal',
#   'Lisbon',
#   12758,
#   'Istanbul Kebab Pizza - Alameda',
#   'delivered',
#   'NA',
#   'Pizza',
#   'android',
#   1,
#   10.0,
#   0.0,
#   16.3,
#   2382),
#  ('2020-02-28 00:00:00',
#   'Portugal',
#   'Lisbon',
#   6631,
#   'A-100 - Lisboa',
#   'delivered',
#   'NA',
#   'Burgers',
#   'ios',
#   2,
#   16.96,
#   0.0,
#   13.6,
#   3383),
#  ('2020-02-28 00:00:00',
#   'Portugal',
#   'Lisbon',
#   10535,
#   'La Paparrucha - Parrilla Argentina',
#   'delivered',
#   'NA',
#   'South American',
#   'ios',
#   3,
#   25.15,
#   4.2,
#   26.1,
#   4384),
#  ('2020-02-28 00:00:00',
#   'Portugal',
#   'Lisbon',
#   9695,
#   'Choupana Caffe',
#   'delivered',
#   'NA',
#   'Brunch',
#   'ios',
#   3,
#   16.0,
#   0.0,
#   11.6,
#   5385)]

# %%
c.execute("SELECT *\
from payment limit 5")
          
          
rows = c.fetchall()
rows
# Out:
# [(1381, 'cashless', 'BANKINTER S.A.'),
#  (2382, 'cashless', 'BANCO COMERCIAL PORTUGUES S.A.'),
#  (3383, 'cashless', 'BANCO COMERCIAL PORTUGUES S.A.'),
#  (4384, 'cashless', 'ING BANK N.V.'),
#  (5385, 'cashless', 'INTESA SANPAOLO SPA')]

# %%
sql = """
SELECT 
    Order_ID, CASE CAST (strftime('%w',
        created_date) AS integer)
      WHEN 0 THEN 'Sunday'
      WHEN 1 THEN 'Monday'
      WHEN 2 THEN 'Tuesday'
      WHEN 3 THEN 'Wednesday'
      WHEN 4 THEN 'Thursday'
      WHEN 5 THEN 'Friday'
    ELSE
    'Saturday'
  END
    AS weekday,
    Payment_Method 
FROM orders 
    LEFT JOIN orders openOrderParts ON openOrderParts.order_number = openOrderParts.order_number 
        AND openOrderParts.date_deleted IS NULL
WHERE date_deleted IS NOT NULL AND openOrderParts IS NULL
GROUP BY order_number
# Out:
#   Input In [29]
#     GROUP BY order_number
#
# ^
# SyntaxError: EOF while scanning triple-quoted string literal

# %%
sql = """
  SELECT
  o.Order_ID,
    strftime('%W',
      o.created_date) week,
    CASE CAST (strftime('%w',
        o.created_date) AS integer)
      WHEN 0 THEN 'Sunday'
      WHEN 1 THEN 'Monday'
      WHEN 2 THEN 'Tuesday'
      WHEN 3 THEN 'Wednesday'
      WHEN 4 THEN 'Thursday'
      WHEN 5 THEN 'Friday'
    ELSE
    'Saturday'
  END
    AS weekday,
    o.City,
    Payment_Method,
    o.Order_State,
    COUNT(o.Order_ID) count
  FROM
    orders o
  JOIN
    payment p
  ON
    o.Order_ID = p.Order_ID
    LEFT JOIN orders a ON o.Order_ID = a.Order_ID 
        AND a.count IS NULL
WHERE count IS NOT NULL AND a IS NULL

  and 
    Order_State = "delivered"
  GROUP BY
    week,
    weekday,
    City,
    Payment_Method,o.Order_ID
    
    
"""

execute_sql(sql)

# %%
sql = """
SELECT
strftime('%W',
      created_date) week,
      city,
   CASE CAST (strftime('%w',
        created_date) AS integer)
      WHEN 0 THEN 'Sunday'
      WHEN 1 THEN 'Monday'
      WHEN 2 THEN 'Tuesday'
      WHEN 3 THEN 'Wednesday'
      WHEN 4 THEN 'Thursday'
      WHEN 5 THEN 'Friday'
    ELSE
    'Saturday'
  END
    AS weekday,
    Payment_Method,
    CASE WHEN COUNT(*) = COUNT(Payment_Method) THEN COUNT(Payment_Method) END AS date_deleted
  FROM
    orders o
  JOIN
    payment p
  ON
    o.Order_ID = p.Order_ID
  WHERE
    Order_State = "delivered" 
  GROUP BY
  week,
  city,
    weekday,
    Payment_Method
    """

execute_sql(sql)

# %%
SELECT orders.city, orders.week, payments.payment_method, orders.weekday_name, COUNT(orders.order_id) as order_count
FROM order_table as orders
INNER JOIN payment_table as payments ON orders.order_id = payments.order_id
GROUP BY orders.city, orders.week, payments.payment_method, orders.weekday_name
HAVING order_count = (
    SELECT MAX(order_count) FROM (
        SELECT COUNT(orders.order_id) as order_count
        FROM order_table as orders
        INNER JOIN payment_table as payments ON orders.order_id = payments.order_id
        WHERE orders.city = orders.city AND orders.week = orders.week AND payments.payment_method = payments.payment_method
        GROUP BY orders.weekday_name
    ) as t
)

# %% [markdown]
# This query first joins the order_table and payment_table on the order_id column, then groups the results by city, week, payment_method, and weekday_name. It then uses a subquery to find the maximum order count for each payment method, week, and city, and filters the results to only include rows where the order count is equal to the maximum order count. If there were no cash orders during the week in a city, the query will return NULL for the weekday with the highest order count. If several days during the week have the same count of delivered orders per payment method, the query will return the weekday name of an earlier day (Sunday is considered the first day of the week with an index of 0).

# %%
SELECT orders.city, DATEPART(wk, CONVERT(date, orders.created_date, 105)) as week, payments.payment_method, DATENAME(dw, CONVERT(date, orders.created_date, 105)) as weekday_name, COUNT(orders.order_id) as order_count
FROM order_table as orders
INNER JOIN payment_table as payments ON orders.order_id = payments.order_id
GROUP BY orders.city, DATEPART(wk, CONVERT(date, orders.created_date, 105)), payments.payment_method, DATENAME(dw, CONVERT(date, orders.created_date, 105))
HAVING order_count = (
    SELECT MAX(order_count) FROM (
        SELECT COUNT(orders.order_id) as order_count
        FROM order_table as orders
        INNER JOIN payment_table as payments ON orders.order_id = payments.order_id
        WHERE orders.city = orders.city AND DATEPART(wk, CONVERT(date, orders.created_date, 105)) = DATEPART(wk, CONVERT(date, orders.created_date, 105)) AND payments.payment_method = payments.payment_method
        GROUP BY DATENAME(dw, CONVERT(date, orders.created_date, 105))
    ) as t
)

# %% [markdown]
# This query uses the CONVERT function to convert the created_date string to a date data type, using the format code 105 to specify the "dd.mm.yyyy" format. It then uses the DATEPART function to extract the week from the converted date, and the DATENAME function to extract the weekday name. It then groups the results by city, week, payment_method, and weekday_name, and uses a subquery to find the maximum order count for each payment method, week, and city. If there were no cash orders during the week in a city, the query will return NULL for the weekday with the highest order count. If several days during the week have the same count of delivered orders per payment method, the query will return the weekday name of an earlier day (Sunday is considered the first day of the week with an index of 0).

# %%
sql = """
SELECT
o.city, strftime('%W', o.created_date) week,
p.payment_method,
CASE CAST (strftime('%w',
        o.created_date) AS integer)
      WHEN 0 THEN 'Sunday'
      WHEN 1 THEN 'Monday'
      WHEN 2 THEN 'Tuesday'
      WHEN 3 THEN 'Wednesday'
      WHEN 4 THEN 'Thursday'
      WHEN 5 THEN 'Friday'
    ELSE
    'Saturday'
  END
    AS weekday,
COUNT(o.order_id) order_count
FROM orders o
INNER JOIN payment p
ON o.order_id = p.order_id
GROUP BY o.city, week, p.payment_method, weekday
HAVING order_count = (
    SELECT MAX(order_count) FROM (
        SELECT COUNT(o.order_id) as order_count, p.payment_method, strftime('%W', o.created_date) week 
        FROM orders o
        Left JOIN payment p
        ON o.order_id = p.order_id
        WHERE o.city = o.city
        AND strftime('%W', o.created_date) = week
        GROUP BY o.city, week, p.payment_method
    ) as t
    WHERE p.payment_method = t.payment_method
)

"""

execute_sql(sql)
# Out:
# Empty DataFrame
# Columns: [city, week, payment_method, weekday, order_count]
# Index: []

# %%
sql = """
SELECT
strftime('%W', created_date) week,
o.city, 
p.payment_method,
CASE CAST (strftime('%w',
        created_date) AS integer)
      WHEN 0 THEN 'Sunday'
      WHEN 1 THEN 'Monday'
      WHEN 2 THEN 'Tuesday'
      WHEN 3 THEN 'Wednesday'
      WHEN 4 THEN 'Thursday'
      WHEN 5 THEN 'Friday'
    ELSE
    'Saturday'
  END
    AS weekday,
COUNT(o.order_id) order_count
FROM orders o
INNER JOIN payment p
ON o.order_id = p.order_id
GROUP BY o.city, week, p.payment_method, weekday
HAVING order_count = (
    SELECT MAX(order_count) FROM (
        SELECT COUNT(o.order_id) as order_count,
        CASE CAST (strftime('%w',
        created_date) AS integer)
      WHEN 0 THEN 'Sunday'
      WHEN 1 THEN 'Monday'
      WHEN 2 THEN 'Tuesday'
      WHEN 3 THEN 'Wednesday'
      WHEN 4 THEN 'Thursday'
      WHEN 5 THEN 'Friday'
    ELSE
    'Saturday'
  END AS weekday
        FROM orders o
        Left JOIN payment p
        ON o.order_id = p.order_id
        AND order_count IS NULL
        WHERE 
        o.order_id = o.order_id
        GROUP BY o.city, p.payment_method,
        weekday,strftime('%W', created_date)
    ) as t
)


"""

execute_sql(sql)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\io\sql.py:2020, in SQLiteDatabase.execute(self, *args, **kwargs)
#    2019 try:
# -> 2020     cur.execute(*args, **kwargs)
#    2021     return cur
#
# OperationalError: misuse of aggregate: COUNT()
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Input In [58], in <cell line: 51>()
#       1 sql = """
#       2 SELECT
#       3 strftime('%W', created_date) week,
#    (...)
#      48
#      49 """
# ---> 51 execute_sql(sql)
#
# Input In [25], in execute_sql(sql)
#       1 def execute_sql(sql):
#       2     """
#       3     Functions to execute results and return as dataframe
#       4     """
# ----> 6     result = pd.read_sql(sql, conn)
#       7     return pd.DataFrame(result)
#
# File ~\anaconda3\lib\site-packages\pandas\io\sql.py:566, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     563 pandas_sql = pandasSQL_builder(con)
#     565 if isinstance(pandas_sql, SQLiteDatabase):
# --> 566     return pandas_sql.read_query(
#     567         sql,
#     568         index_col=index_col,
#     569         params=params,
#     570         coerce_float=coerce_float,
#     571         parse_dates=parse_dates,
#     572         chunksize=chunksize,
#     573     )
#     575 try:
#     576     _is_table_name = pandas_sql.has_table(sql)
#
# File ~\anaconda3\lib\site-packages\pandas\io\sql.py:2080, in SQLiteDatabase.read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize, dtype)
#    2068 def read_query(
#    2069     self,
#    2070     sql,
#    (...)
#    2076     dtype: DtypeArg | None = None,
#    2077 ):
#    2079     args = _convert_params(sql, params)
# -> 2080     cursor = self.execute(*args)
#    2081     columns = [col_desc[0] for col_desc in cursor.description]
#    2083     if chunksize is not None:
#
# File ~\anaconda3\lib\site-packages\pandas\io\sql.py:2032, in SQLiteDatabase.execute(self, *args, **kwargs)
#    2029     raise ex from inner_exc
#    2031 ex = DatabaseError(f"Execution failed on sql '{args[0]}': {exc}")
# -> 2032 raise ex from exc
#
# DatabaseError: Execution failed on sql '
# SELECT
# strftime('%W', created_date) week,
# o.city,
# p.payment_method,
# CASE CAST (strftime('%w',
#         created_date) AS integer)
#       WHEN 0 THEN 'Sunday'
#       WHEN 1 THEN 'Monday'
#       WHEN 2 THEN 'Tuesday'
#       WHEN 3 THEN 'Wednesday'
#       WHEN 4 THEN 'Thursday'
#       WHEN 5 THEN 'Friday'
#     ELSE
#     'Saturday'
#   END
#     AS weekday,
# COUNT(o.order_id) order_count
# FROM orders o
# INNER JOIN payment p
# ON o.order_id = p.order_id
# GROUP BY o.city, week, p.payment_method, weekday
# HAVING order_count = (
#     SELECT MAX(order_count) FROM (
#         SELECT COUNT(o.order_id) as order_count,
#         CASE CAST (strftime('%w',
#         created_date) AS integer)
#       WHEN 0 THEN 'Sunday'
#       WHEN 1 THEN 'Monday'
#       WHEN 2 THEN 'Tuesday'
#       WHEN 3 THEN 'Wednesday'
#       WHEN 4 THEN 'Thursday'
#       WHEN 5 THEN 'Friday'
#     ELSE
#     'Saturday'
#   END AS weekday
#         FROM orders o
#         Left JOIN payment p
#         ON o.order_id = p.order_id
#          AND order_count IS NULL
#         WHERE
#         o.order_id = o.order_id
#         GROUP BY o.city, p.payment_method,
#         weekday,strftime('%W', created_date)
#     ) as t
# )
#
#
# ': misuse of aggregate: COUNT()

# %% [markdown]
# The query uses the following steps to achieve the desired result:
#
# The INNER JOIN clause is used to join the order_table and payment_table tables based on the order_id column. This allows us to access the data from both tables in a single query.
#
# The GROUP BY clause is used to group the data by city, week, payment_method, and weekday. This will allow us to count the number of orders for each combination of these values.
#
# The COUNT function is used to count the number of orders for each group.
#
# The HAVING clause is used to filter the groups that have the highest number of orders. To do this, we use a subquery to find the maximum number of orders for each group and compare it to the order_count column in the outer query.
#
# The CASE statement is used to convert the day of the week number (0-6) to the corresponding weekday name.
#
# The STRFTIME function is used to extract the week number from the created_date column.
#
# The SUBSTR function is used to extract the year, month, and day from the created_date column and concatenate them into a date string in the format "yyyy-mm-dd". This date string is then cast to a date using the CAST function. The DATENAME function is then used to extract the weekday name from the date.
#
# By following these steps, the query returns the weekday names with the highest number of delivered orders for each of the payment

# %%
SELECT orders.city, STRFTIME('%W', CAST(SUBSTR(orders.created_date, 7, 4) || '-' || SUBSTR(orders.created_date, 4, 2) || '-' || SUBSTR(orders.created_date, 1, 2) as date)) as week, payments.payment_method, DATENAME(dw, CAST(SUBSTR(orders.created_date, 7, 4) || '-' || SUBSTR(orders.created_date, 4, 2) || '-' || SUBSTR(orders.created_date, 1, 2) as date)) as weekday_name, COUNT(orders.order_id) as order_count
FROM order_table as orders
INNER JOIN payment_table as payments ON orders.order_id = payments.order_id
GROUP BY orders.city, STRFTIME('%W', CAST(SUBSTR(orders.created_date, 7, 4) || '-' || SUBSTR(orders.created_date, 4, 2) || '-' || SUBSTR(orders.created_date, 1, 2) as date)), payments.payment_method, DATENAME(dw, CAST(SUBSTR(orders.created_date, 7, 4) || '-' || SUBSTR(orders.created_date, 4, 2) || '-' || SUBSTR(orders.created_date, 1, 2) as date))
HAVING order_count = (
    SELECT MAX(order_count) FROM (
        SELECT COUNT(orders.order_id) as order_count
        FROM order_table as orders
        INNER JOIN payment_table as payments ON orders.order_id = payments.order_id
        WHERE orders.city = orders.city AND STRFTIME('%W', CAST(SUBSTR(orders.created_date, 7, 4) || '-' || SUBSTR(orders.created_date, 4, 2) || '-' || SUBSTR(orders.created_date, 1, 2) as date)) = STRFTIME('%W', CAST(SUBSTR(orders.created_date, 7, 4) || '-' || SUBSTR(orders.created_date, 4, 2) || '-' || SUBSTR(orders.created_date, 1, 2

# %%
SELECT orders.city, DATEPART(wk, orders.created_date) as week, payments.payment_method, DATENAME(dw, orders.created_date) as weekday_name, COUNT(orders.order_id) as order_count
FROM order_table as orders
INNER JOIN payment_table as payments ON orders.order_id = payments.order_id
GROUP BY orders.city, DATEPART(wk, orders.created_date), payments.payment_method, DATENAME(dw, orders.created_date)
HAVING order_count = (
    SELECT MAX(order_count) FROM (
        SELECT COUNT(orders.order_id) as order_count
        FROM order_table as orders
        INNER JOIN payment_table as payments ON orders.order_id = payments.order_id
        WHERE orders.city = orders.city AND DATEPART(wk, orders.created_date) = DATEPART(wk, orders.created_date) AND payments.payment_method = payments.payment_method
        GROUP BY DATENAME(dw, orders.created_date)
    ) as t
)

# %%
sql = """
SELECT
  city,
  payment_method,
  strftime('%W', created_date) AS week,
  CASE strftime('%w', created_date)
    WHEN 0 THEN 'Sunday'
    WHEN 1 THEN 'Monday'
    WHEN 2 THEN 'Tuesday'
    WHEN 3 THEN 'Wednesday'
    WHEN 4 THEN 'Thursday'
    WHEN 5 THEN 'Friday'
    WHEN 6 THEN 'Saturday'
  END AS weekday,
  COUNT(*) AS order_count
FROM orders
JOIN payment
ON orders.order_id = payment.order_id
WHERE order_state = 'delivered'
GROUP BY city, payment_method, week, weekday
HAVING COUNT(*) = (SELECT MAX(cnt) FROM (
  SELECT COUNT(*) AS cnt
  FROM orders
  LEFT JOIN payment
  ON orders.order_id = payment.order_id
  WHERE order_state = 'delivered'
  GROUP BY city, strftime('%W', created_date)
) t)
ORDER BY city, payment_method, week, weekday;


"""

execute_sql(sql)
# Out:
#      city payment_method week weekday  order_count
# 0  Lisbon       cashless   06    None        11484

# %%
sql = """
WITH
  table1 AS(
  SELECT
    strftime('%W',
      created_date) week,
    CAST (strftime('%w',
        created_date) AS integer) weekday_num,
    City,
    Payment_Method,
    Order_State,
    COUNT(*) count
  FROM
    orders o
  Left JOIN
    payment p
  ON
    o.Order_ID = p.Order_ID
  WHERE
    Order_State = "delivered"),
rnk_table AS (
  SELECT
    *,
    RANK() OVER (PARTITION BY city,week, Payment_Method ORDER BY count DESC ) AS rnk
  FROM
    table1 )
    SELECT
  week,
  City,
  Payment_Method,
  case
  when
  week=week
  and City = City
  and Payment_Method = Payment_Method
  and count = count
  then min(weekday_num)
  else weekday_num end weekday_num
  
FROM
  rnk_table
WHERE
  rnk = 1
ORDER BY
  week,
  City,
  Payment_Method,
  weekday_num 
  
"""

execute_sql(sql)
# Out:
#   week    City Payment_Method  weekday_num
# 0   08  Lisbon       cashless            5

# %%
pd.set_option('display.max_rows', 200)

# %%
sql = """
WITH
  table1 AS(
  SELECT
    strftime('%W',
      created_date) week,
    CASE CAST (strftime('%w',
        created_date) AS integer)
      WHEN 0 THEN 'Sunday'
      WHEN 1 THEN 'Monday'
      WHEN 2 THEN 'Tuesday'
      WHEN 3 THEN 'Wednesday'
      WHEN 4 THEN 'Thursday'
      WHEN 5 THEN 'Friday'
    ELSE
    'Saturday'
  END
    AS weekday,
    City,
    Payment_Method,
    Order_State,
    COUNT(*) count
  FROM
    orders o
  JOIN
    payment p
  ON
    o.Order_ID = p.Order_ID
  WHERE
    Order_State = "delivered"
  GROUP BY
    week,
    weekday,
    City,
    Payment_Method)
  SELECT
    *,
    DENSE_RANK() OVER (PARTITION BY city,week, Payment_Method ORDER BY count DESC ) AS rnk
  FROM
    table1
    """

execute_sql(sql)
# Out:
#     week    weekday    City Payment_Method Order_State  count  rnk
# 0     00     Sunday   Accra           cash   delivered     98    1
# 1     00   Saturday   Accra           cash   delivered     83    2
# 2     00  Wednesday   Accra           cash   delivered     59    3
# 3     00   Thursday   Accra           cash   delivered     51    4
# 4     00     Friday   Accra           cash   delivered     31    5
# 5     00     Sunday   Accra       cashless   delivered    100    1
# 6     00   Saturday   Accra       cashless   delivered     86    2
# 7     00   Thursday   Accra       cashless   delivered     75    3
# 8     00  Wednesday   Accra       cashless   delivered     65    4
# 9     00     Friday   Accra       cashless   delivered     45    5
# 10    01   Saturday   Accra           cash   delivered     87    1
# 11    01     Monday   Accra           cash   delivered     85    2
# 12    01     Sunday   Accra           cash   delivered     79    3
# 13    01  Wednesday   Accra           cash   delivered     74    4
# 14    01    Tuesday   Accra           cash   delivered     67    5
# 15    01     Friday   Accra           cash   delivered     66    6
# 16    01   Thursday   Accra           cash   delivered     51    7
# 17    01     Sunday   Accra       cashless   delivered    100    1
# 18    01     Monday   Accra       cashless   delivered     90    2
# 19    01  Wednesday   Accra       cashless   delivered     81    3
# 20    01   Thursday   Accra       cashless   delivered     77    4
# 21    01   Saturday   Accra       cashless   delivered     74    5
# 22    01    Tuesday   Accra       cashless   delivered     70    6
# 23    01     Friday   Accra       cashless   delivered     68    7
# 24    02    Tuesday   Accra           cash   delivered     94    1
# 25    02   Saturday   Accra           cash   delivered     89    2
# 26    02     Sunday   Accra           cash   delivered     89    2
# 27    02     Monday   Accra           cash   delivered     86    3
# 28    02  Wednesday   Accra           cash   delivered     86    3
# 29    02   Thursday   Accra           cash   delivered     65    4
# 30    02     Friday   Accra           cash   delivered     62    5
# 31    02    Tuesday   Accra       cashless   delivered    117    1
# 32    02  Wednesday   Accra       cashless   delivered    105    2
# 33    02     Monday   Accra       cashless   delivered     98    3
# 34    02     Sunday   Accra       cashless   delivered     96    4
# 35    02   Thursday   Accra       cashless   delivered     95    5
# 36    02   Saturday   Accra       cashless   delivered     85    6
# 37    02     Friday   Accra       cashless   delivered     77    7
# 38    03    Tuesday   Accra           cash   delivered    120    1
# 39    03  Wednesday   Accra           cash   delivered    111    2
# 40    03   Saturday   Accra           cash   delivered    106    3
# 41    03     Sunday   Accra           cash   delivered    103    4
# 42    03     Monday   Accra           cash   delivered     91    5
# 43    03   Thursday   Accra           cash   delivered     91    5
# 44    03     Friday   Accra           cash   delivered     88    6
# 45    03     Sunday   Accra       cashless   delivered    133    1
# 46    03  Wednesday   Accra       cashless   delivered    125    2
# 47    03    Tuesday   Accra       cashless   delivered    117    3
# 48    03     Monday   Accra       cashless   delivered    113    4
# 49    03   Saturday   Accra       cashless   delivered    107    5
# 50    03   Thursday   Accra       cashless   delivered    106    6
# 51    03     Friday   Accra       cashless   delivered     95    7
# 52    04  Wednesday   Accra           cash   delivered    120    1
# 53    04     Sunday   Accra           cash   delivered    119    2
# 54    04   Saturday   Accra           cash   delivered    117    3
# 55    04    Tuesday   Accra           cash   delivered    115    4
# 56    04     Monday   Accra           cash   delivered    109    5
# 57    04   Thursday   Accra           cash   delivered     96    6
# 58    04     Friday   Accra           cash   delivered     80    7
# 59    04     Sunday   Accra       cashless   delivered    182    1
# 60    04  Wednesday   Accra       cashless   delivered    136    2
# 61    04    Tuesday   Accra       cashless   delivered    130    3
# 62    04   Thursday   Accra       cashless   delivered    128    4
# 63    04     Monday   Accra       cashless   delivered    125    5
# 64    04   Saturday   Accra       cashless   delivered    123    6
# 65    04     Friday   Accra       cashless   delivered     96    7
# 66    05   Saturday   Accra           cash   delivered    119    1
# 67    05  Wednesday   Accra           cash   delivered    115    2
# 68    05     Monday   Accra           cash   delivered    114    3
# 69    05    Tuesday   Accra           cash   delivered    113    4
# 70    05     Sunday   Accra           cash   delivered    103    5
# 71    05   Thursday   Accra           cash   delivered     95    6
# 72    05     Friday   Accra           cash   delivered     72    7
# 73    05     Sunday   Accra       cashless   delivered    182    1
# 74    05    Tuesday   Accra       cashless   delivered    169    2
# 75    05     Monday   Accra       cashless   delivered    162    3
# 76    05  Wednesday   Accra       cashless   delivered    147    4
# 77    05   Saturday   Accra       cashless   delivered    145    5
# 78    05   Thursday   Accra       cashless   delivered    134    6
# 79    05     Friday   Accra       cashless   delivered     89    7
# 80    06     Sunday   Accra           cash   delivered    125    1
# 81    06    Tuesday   Accra           cash   delivered    120    2
# 82    06   Thursday   Accra           cash   delivered    114    3
# 83    06  Wednesday   Accra           cash   delivered    104    4
# 84    06     Monday   Accra           cash   delivered     92    5
# 85    06     Friday   Accra           cash   delivered     89    6
# 86    06   Saturday   Accra           cash   delivered     87    7
# 87    06   Saturday   Accra       cashless   delivered    185    1
# 88    06   Thursday   Accra       cashless   delivered    171    2
# 89    06     Sunday   Accra       cashless   delivered    167    3
# 90    06    Tuesday   Accra       cashless   delivered    165    4
# 91    06  Wednesday   Accra       cashless   delivered    153    5
# 92    06     Monday   Accra       cashless   delivered    141    6
# 93    06     Friday   Accra       cashless   delivered    138    7
# 94    07     Monday   Accra           cash   delivered    135    1
# 95    07   Thursday   Accra           cash   delivered    127    2
# 96    07    Tuesday   Accra           cash   delivered    127    2
# 97    07   Saturday   Accra           cash   delivered    124    3
# 98    07     Sunday   Accra           cash   delivered    114    4
# 99    07  Wednesday   Accra           cash   delivered    114    4
# 100   07     Friday   Accra           cash   delivered     84    5
# 101   07   Thursday   Accra       cashless   delivered    226    1
# 102   07    Tuesday   Accra       cashless   delivered    194    2
# 103   07  Wednesday   Accra       cashless   delivered    193    3
# 104   07     Monday   Accra       cashless   delivered    189    4
# 105   07   Saturday   Accra       cashless   delivered    180    5
# 106   07     Sunday   Accra       cashless   delivered    170    6
# 107   07     Friday   Accra       cashless   delivered    148    7
# 108   08  Wednesday   Accra           cash   delivered    145    1
# 109   08     Monday   Accra           cash   delivered    124    2
# 110   08    Tuesday   Accra           cash   delivered    121    3
# 111   08   Thursday   Accra           cash   delivered    117    4
# 112   08     Friday   Accra           cash   delivered     73    5
# 113   08  Wednesday   Accra       cashless   delivered    210    1
# 114   08   Thursday   Accra       cashless   delivered    183    2
# 115   08     Monday   Accra       cashless   delivered    162    3
# 116   08    Tuesday   Accra       cashless   delivered    160    4
# 117   08     Friday   Accra       cashless   delivered    133    5
# 118   00     Friday  Lisbon       cashless   delivered   1110    1
# 119   00   Thursday  Lisbon       cashless   delivered   1104    2
# 120   00  Wednesday  Lisbon       cashless   delivered    882    3
# 121   00     Sunday  Lisbon       cashless   delivered    788    4
# 122   00   Saturday  Lisbon       cashless   delivered    784    5
# 123   01   Thursday  Lisbon       cashless   delivered   1497    1
# 124   01     Friday  Lisbon       cashless   delivered   1463    2
# 125   01  Wednesday  Lisbon       cashless   delivered   1000    3
# 126   01    Tuesday  Lisbon       cashless   delivered    979    4
# 127   01     Sunday  Lisbon       cashless   delivered    949    5
# 128   01   Saturday  Lisbon       cashless   delivered    944    6
# 129   01     Monday  Lisbon       cashless   delivered    832    7
# 130   02  Wednesday  Lisbon       cashless   delivered   1374    1
# 131   02   Thursday  Lisbon       cashless   delivered   1360    2
# 132   02     Friday  Lisbon       cashless   delivered   1356    3
# 133   02     Sunday  Lisbon       cashless   delivered   1156    4
# 134   02    Tuesday  Lisbon       cashless   delivered   1123    5
# 135   02   Saturday  Lisbon       cashless   delivered   1063    6
# 136   02     Monday  Lisbon       cashless   delivered    995    7
# 137   03   Thursday  Lisbon       cashless   delivered   1674    1
# 138   03  Wednesday  Lisbon       cashless   delivered   1602    2
# 139   03    Tuesday  Lisbon       cashless   delivered   1504    3
# 140   03     Friday  Lisbon       cashless   delivered   1480    4
# 141   03     Monday  Lisbon       cashless   delivered   1264    5
# 142   03     Sunday  Lisbon       cashless   delivered   1140    6
# 143   03   Saturday  Lisbon       cashless   delivered   1132    7
# 144   04   Thursday  Lisbon       cashless   delivered   1828    1
# 145   04  Wednesday  Lisbon       cashless   delivered   1773    2
# 146   04     Friday  Lisbon       cashless   delivered   1715    3
# 147   04    Tuesday  Lisbon       cashless   delivered   1432    4
# 148   04     Sunday  Lisbon       cashless   delivered   1329    5
# 149   04   Saturday  Lisbon       cashless   delivered   1311    6
# 150   04     Monday  Lisbon       cashless   delivered   1288    7
# 151   05   Thursday  Lisbon       cashless   delivered   1855    1
# 152   05  Wednesday  Lisbon       cashless   delivered   1781    2
# 153   05     Friday  Lisbon       cashless   delivered   1725    3
# 154   05    Tuesday  Lisbon       cashless   delivered   1451    4
# 155   05     Sunday  Lisbon       cashless   delivered   1420    5
# 156   05     Monday  Lisbon       cashless   delivered   1340    6
# 157   05   Saturday  Lisbon       cashless   delivered   1246    7
# 158   06     Friday  Lisbon       cashless   delivered   2101    1
# 159   06   Thursday  Lisbon       cashless   delivered   1906    2
# 160   06  Wednesday  Lisbon       cashless   delivered   1830    3
# 161   06    Tuesday  Lisbon       cashless   delivered   1577    4
# 162   06     Sunday  Lisbon       cashless   delivered   1402    5
# 163   06     Monday  Lisbon       cashless   delivered   1394    6
# 164   06   Saturday  Lisbon       cashless   delivered   1274    7
# 165   07   Thursday  Lisbon       cashless   delivered   1915    1
# 166   07  Wednesday  Lisbon       cashless   delivered   1882    2
# 167   07     Friday  Lisbon       cashless   delivered   1750    3
# 168   07    Tuesday  Lisbon       cashless   delivered   1454    4
# 169   07     Sunday  Lisbon       cashless   delivered   1450    5
# 170   07     Monday  Lisbon       cashless   delivered   1398    6
# 171   07   Saturday  Lisbon       cashless   delivered   1312    7
# 172   08  Wednesday  Lisbon       cashless   delivered   2307    1
# 173   08   Thursday  Lisbon       cashless   delivered   2201    2
# 174   08     Friday  Lisbon       cashless   delivered   2030    3
# 175   08    Tuesday  Lisbon       cashless   delivered   1808    4
# 176   08     Monday  Lisbon       cashless   delivered   1545    5

# %%
sql = """
WITH
  table1 AS(
  SELECT
    strftime('%W',
      created_date) week,
    CASE CAST (strftime('%w',
        created_date) AS integer)
      WHEN 0 THEN 'Sunday'
      WHEN 1 THEN 'Monday'
      WHEN 2 THEN 'Tuesday'
      WHEN 3 THEN 'Wednesday'
      WHEN 4 THEN 'Thursday'
      WHEN 5 THEN 'Friday'
    ELSE
    'Saturday'
  END
    AS weekday,
    City,
    Payment_Method,
    Order_State,
    COUNT(*) count
  FROM
    orders o
  JOIN
    payment p
  ON
    o.Order_ID = p.Order_ID
  WHERE
    Order_State = "delivered"
  GROUP BY
    week,
    weekday,
    City,
    Payment_Method),
  rnk_table AS (
  SELECT
    *,
    RANK() OVER (PARTITION BY city,week, Payment_Method ORDER BY count DESC ) AS rnk
  FROM
    table1 )
SELECT
  week,
  City,
  Payment_Method,
  weekday,
  count no_of_delivered_orders
FROM
  rnk_table
WHERE
  rnk = 1
ORDER BY
  week,
  City,
  Payment_Method,
  weekday 
  
"""

execute_sql(sql)
# Out:
#    week    City Payment_Method    weekday  no_of_delivered_orders
# 0    00   Accra           cash     Sunday                      98
# 1    00   Accra       cashless     Sunday                     100
# 2    00  Lisbon       cashless     Friday                    1110
# 3    01   Accra           cash   Saturday                      87
# 4    01   Accra       cashless     Sunday                     100
# 5    01  Lisbon       cashless   Thursday                    1497
# 6    02   Accra           cash    Tuesday                      94
# 7    02   Accra       cashless    Tuesday                     117
# 8    02  Lisbon       cashless  Wednesday                    1374
# 9    03   Accra           cash    Tuesday                     120
# 10   03   Accra       cashless     Sunday                     133
# 11   03  Lisbon       cashless   Thursday                    1674
# 12   04   Accra           cash  Wednesday                     120
# 13   04   Accra       cashless     Sunday                     182
# 14   04  Lisbon       cashless   Thursday                    1828
# 15   05   Accra           cash   Saturday                     119
# 16   05   Accra       cashless     Sunday                     182
# 17   05  Lisbon       cashless   Thursday                    1855
# 18   06   Accra           cash     Sunday                     125
# 19   06   Accra       cashless   Saturday                     185
# 20   06  Lisbon       cashless     Friday                    2101
# 21   07   Accra           cash     Monday                     135
# 22   07   Accra       cashless   Thursday                     226
# 23   07  Lisbon       cashless   Thursday                    1915
# 24   08   Accra           cash  Wednesday                     145
# 25   08   Accra       cashless  Wednesday                     210
# 26   08  Lisbon       cashless  Wednesday                    2307

# %% [markdown]
#  SELECT \
#   case cast (strftime('%w', created_date) as integer)\
#   when 0 then 'Sunday'\
#   when 1 then 'Monday'\
#   when 2 then 'Tuesday'\
#   when 3 then 'Wednesday'\
#   when 4 then 'Thursday'\
#   when 5 then 'Friday'\
#   else 'Saturday' end as weekday\
#           FROM orders limit 5")
# rows = c.fetchall()
# rows
